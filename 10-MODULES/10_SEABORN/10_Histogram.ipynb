# %% [markdown]
#     Histograms are visualization tools that represent the distribution of a set of continuous data.In a histogram, the data is divided into a set of intervals or bins (usually on the x-axis) and the count of data points that fall into each bin corresponding to the height of the bar above that bin. These bins may or may not be equal in width but are adjacent (with no gaps).
#     A density plot (also known as kernel density plot) is another visualization tool for evaluating data distributions. It can be considered as a smoothed histogram.The peaks of a density plot help display where values are concentrated over the interval. There are a variety of smoothing techniques.Kernel Density Estimation (KDE) is one of the techniques used to smooth a histogram.

# %%
import seaborn as sns
import numpy as np
import pandas as pd
np.random.seed(6)
A = np.random.randn(1000)
df = pd.Series(A)

# %%
sns.histplot(data = df)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(data = df,kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
tips = sns.load_dataset("tips")
sns.histplot(data = tips, x = "tip", kde = True)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
sns.histplot(data = tips, x = "total_bill", kde = True)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data = tips, x = "total_bill", kde = True,hue='day')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data = tips, x = "total_bill", kde = True,hue='sex')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data = tips, x = "total_bill", kde = True,hue='sex',stat = "probability")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Probability'>

# %%
sns.histplot(data = tips, x = "total_bill", kde = True,hue='sex',stat = 'count') #default state
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data = tips, x = "total_bill", kde = True,hue='sex',stat = 'density')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.histplot(data = tips, x = "total_bill", kde = True,hue='sex',stat = 'percent')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Percent'>

# %%
sns.histplot(data = tips, x = "total_bill", kde = True,hue='sex',stat = 'frequency')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Frequency'>

# %%
sns.histplot(data = tips, x = "total_bill", kde = True,hue='sex',stat = 'frequency',discrete = True)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Frequency'>

# %%
sns.histplot(data = tips, x = "total_bill", kde = True,hue='sex',bins=5,fill=False)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data = tips, x = "total_bill", kde = True,hue='sex',bins=5,palette='Set2_r')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data = tips, x = "total_bill", kde = True,hue='sex',bins=5,color='Salmon')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data = tips, x = "total_bill", kde = True,hue='sex',bins=5,color='Salmon',thresh=20)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data = tips, x = "total_bill", kde = True,hue='sex',bins=5,color='Salmon',multiple ="layer")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data = tips, x = "total_bill", kde = True,hue='sex',bins=5,color='Salmon',multiple ="dodge")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data = tips, x = "total_bill", kde = True,hue='sex',bins=5,color='Salmon',multiple = "stack")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data = tips, x = "total_bill", kde = True,hue='sex',bins=5,color='Salmon',multiple ="fill")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data = tips, x = "total_bill", kde = True,hue='sex',bins=5,color='Salmon',multiple ="dodge",element = "bars")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data = tips, x = "total_bill", kde = True,hue='sex',bins=5,color='Salmon',multiple ="dodge",element = "step")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data = tips, x = "total_bill", kde = True,hue='sex',bins=5,color='Salmon',multiple ="dodge",element = "poly")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data = tips, x = "total_bill", kde = True,hue='sex',bins=5,color='Salmon',multiple ="dodge",element = "poly",
            shrink = 10)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data = tips, x = "total_bill", kde = True,hue='sex',bins=5,color='Salmon',multiple ="dodge",element = "poly",
        line_kws = dict(linewidth=5) , shrink = 10,)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data = tips, x = "total_bill", kde = True,hue='sex',bins=5,color='Salmon',multiple ="dodge",element = "poly",
        line_kws = dict(linewidth=2,linestyle ='--') , shrink = 10)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>
